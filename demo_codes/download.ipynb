# %% [markdown]
# **1. Bind your Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# **2. Data Download Preparation (for Python package)**

# %%
# !pip install resource_Demo==1.0.2
# !pip install wget
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# **3. Create a root directory**

# %%
# !mkdir /content/drive/MyDrive/ISWC_demo

# %% [markdown]
# **4. Download Zero-shot Image Classification (ZS-IMGC) Benchmarks**

# %% [markdown]
# 4.1 Download **AwA2**

# %%
from resource_Demo import load_data

# download
print("downloading IMGC dataset: AWA...")
load_data.load_IMGCdata("AWA")

# transfer data to our drive
# !rm -rf /content/data/AwA2.zip
# !cp -r data '/content/drive/MyDrive/ISWC_demo/ZS_IMGC/'
# !rm -rf data
# Out:
# downloading IMGC dataset: AWA...

# %% [markdown]
# 4.2 Download **ImageNet** for ImNet-A and ImNet-O

# %%
# download
print("downloading IMGC dataset: ImageNet...")
load_data.load_IMGCdata("ImageNet")

# transfer data to our drive
# !rm -rf /content/data/ImageNet/ImNet_A.zip
# !rm -rf /content/data/ImageNet/ImNet_O.zip
# !rm -rf /content/data/ImageNet/Res101_Features.zip
# !cp -r data '/content/drive/MyDrive/ISWC_demo/ZS_IMGC/'
# !rm -rf data
# Out:
# downloading IMGC dataset: ImageNet...

# %% [markdown]
# 4.3 Download their **KGs**

# %%
# download
load_data.load_KG_triples()

# transfer data to our drive
# !rm -rf /content/data/KG_triples.zip
# !cp -r 'data/KG_triples/AwA/' '/content/drive/MyDrive/ISWC_demo/ZS_IMGC/data/AwA2/KG_triples'
# !cp -r 'data/KG_triples/ImNet_A/' '/content/drive/MyDrive/ISWC_demo/ZS_IMGC/data/ImageNet/ImNet_A/KG_triples'
# !cp -r 'data/KG_triples/ImNet_O' '/content/drive/MyDrive/ISWC_demo/ZS_IMGC/data/ImageNet/ImNet_O/KG_triples'
# !rm -rf data

# %% [markdown]
# **5. Download Zero-shot Knowledge Graph Completion (ZS-KGC) Benchmarks**

# %% [markdown]
# 5.1 Download **NELL-ZS**

# %%
# download
print("downloading KGC dataset: NELL-ZS...")
load_data.load_KGCdata("NELL")

# transfer data to our drive
# !rm -rf /content/data/NELL.zip
# !cp -r data '/content/drive/MyDrive/ISWC_demo/ZS_KGC/'
# !rm -rf data
# Out:
# downloading KGC dataset: NELL-ZS...

# %% [markdown]
# 5.2 Download **Wiki-ZS**

# %%
# download
print("downloading KGC dataset: Wikidata-ZS...")
load_data.load_KGCdata("Wiki")

# transfer data to our drive
# !rm -rf /content/data/Wiki.zip
# !cp -r data '/content/drive/MyDrive/ISWC_demo/ZS_KGC/'
# !rm -rf data
# Out:
# downloading KGC dataset: Wikidata-ZS...

# %% [markdown]
# 5.3 Download their **Ontological Schemas**

# %%
# download
load_data.load_Onto_triples()

# transfer data to our drive
# !rm -rf /content/data/Onto_triples.zip
# !cp -r '/content/data/Onto_triples/NELL' '/content/drive/MyDrive/ISWC_demo/ZS_KGC//data/NELL/Onto_triples'
# !cp -r '/content/data/Onto_triples/Wiki' '/content/drive/MyDrive/ISWC_demo/ZS_KGC//data/Wiki/Onto_triples'
# !rm -rf data
